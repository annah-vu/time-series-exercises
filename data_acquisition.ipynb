# %%
import pandas as pd
import os
import requests
from acquire import get_items, new_stores, get_stores, get_sales, combined_data

# %%
def new_items():
    
    items_list = []

    response = requests.get('https://python.zach.lol/api/v1/items')
    data = response.json()
    n = data['payload']['max_page']

    for i in range(1,n+1):
        url = 'https://python.zach.lol/api/v1/items?page='+str(i)
        response = requests.get(url)
        data = response.json()
        page_items = data['payload']['items']
        items_list += page_items
        
        return pd.DataFrame(items_list)

# %%
items = get_items()

# %%
def get_items():
    if os.path.isfile('items.csv'):
        df = pd.read_csv('items.csv', index_col=0)
    else:
        df = new_items()
        df.to_csv('items.csv')
        
    return df

# %%
get_items()
# Out:
#                item_brand  item_id  \
# 0                Riceland        1
# 1                  Caress        2
# 2             Earths Best        3
# 3              Boars Head        4
# 4          Back To Nature        5
# 5            Sally Hansen        6
# 6      Twinings Of London        7
# 7           Lea & Perrins        8
# 8            Van De Kamps        9
# 9                   Ahold       10
# 10             Honest Tea       11
# 11                Mueller       12
# 12  Garnier Nutritioniste       13
# 13                Pamprin       14
# 14                  Suave       15
# 15             Burts Bees       16
# 16                  Ducal       17
# 17                 Scotch       18
# 18                Careone       19
# 19           Usda Produce       20
#
#                                             item_name  item_price  \
# 0                      Riceland American Jazmine Rice        0.84
# 1   Caress Velvet Bliss Ultra Silkening Beauty Bar...        6.44
# ...

# %%
new_stores()
# Out:
#              store_address   store_city  store_id store_state store_zipcode
# 0   12125 Alamo Ranch Pkwy  San Antonio         1          TX         78253
# 1         9255 FM 471 West  San Antonio         2          TX         78251
# 2  2118 Fredericksburg Rdj  San Antonio         3          TX         78201
# 3          516 S Flores St  San Antonio         4          TX         78204
# 4          1520 Austin Hwy  San Antonio         5          TX         78218
# 5       1015 S WW White Rd  San Antonio         6          TX         78220
# 6   12018 Perrin Beitel Rd  San Antonio         7          TX         78217
# 7      15000 San Pedro Ave  San Antonio         8          TX         78232
# 8       735 SW Military Dr  San Antonio         9          TX         78221
# 9     8503 NW Military Hwy  San Antonio        10          TX         78231

# %%
stores = get_stores()

# %%
sales = get_sales()

# %%
sales
# Out:
#         item  sale_amount                      sale_date  sale_id  store
# 0          1         13.0  Tue, 01 Jan 2013 00:00:00 GMT        1      1
# 1          1         11.0  Wed, 02 Jan 2013 00:00:00 GMT        2      1
# 2          1         14.0  Thu, 03 Jan 2013 00:00:00 GMT        3      1
# 3          1         13.0  Fri, 04 Jan 2013 00:00:00 GMT        4      1
# 4          1         10.0  Sat, 05 Jan 2013 00:00:00 GMT        5      1
# ...      ...          ...                            ...      ...    ...
# 912995    50         63.0  Wed, 27 Dec 2017 00:00:00 GMT   912996     10
# 912996    50         59.0  Thu, 28 Dec 2017 00:00:00 GMT   912997     10
# 912997    50         74.0  Fri, 29 Dec 2017 00:00:00 GMT   912998     10
# 912998    50         62.0  Sat, 30 Dec 2017 00:00:00 GMT   912999     10
# 912999    50         82.0  Sun, 31 Dec 2017 00:00:00 GMT   913000     10
#
# [913000 rows x 5 columns]

# %%
# # Creating a dataframe that has all of the data for sales
# # For loop
# # Empty list
# sales_list = []
# # base url for store
# url = 'https://python.zach.lol/api/v1/sales'
# # Get our response using the base url
# response = requests.get('https://python.zach.lol/api/v1/sales')
# # Save the data into a variable - data is a dictionary
# data = response.json()
# # Last page
# n = data['payload']['max_page']
# # Do this process for each page and add the data to the items_list
# for i in range(1,n+1):
#     sales_url = url + '?page='+str(i)
#     response = requests.get(sales_url)
#     data = response.json()
#     page_sales = data['payload']['sales']
#     sales_list += page_sales
#     pd.DataFrame(sales_list)

# %%
sales = get_sales()

# %%
sales.shape
# Out:
# (913000, 5)

# %%
sales.head()
# Out:
#    item  sale_amount                      sale_date  sale_id  store
# 0     1         13.0  Tue, 01 Jan 2013 00:00:00 GMT        1      1
# 1     1         11.0  Wed, 02 Jan 2013 00:00:00 GMT        2      1
# 2     1         14.0  Thu, 03 Jan 2013 00:00:00 GMT        3      1
# 3     1         13.0  Fri, 04 Jan 2013 00:00:00 GMT        4      1
# 4     1         10.0  Sat, 05 Jan 2013 00:00:00 GMT        5      1

# %%
items
# Out:
#     Unnamed: 0             item_brand  item_id  \
# 0            0               Riceland        1
# 1            1                 Caress        2
# 2            2            Earths Best        3
# 3            3             Boars Head        4
# 4            4         Back To Nature        5
# 5            5           Sally Hansen        6
# 6            6     Twinings Of London        7
# 7            7          Lea & Perrins        8
# 8            8           Van De Kamps        9
# 9            9                  Ahold       10
# 10          10             Honest Tea       11
# 11          11                Mueller       12
# 12          12  Garnier Nutritioniste       13
# 13          13                Pamprin       14
# 14          14                  Suave       15
# 15          15             Burts Bees       16
# 16          16                  Ducal       17
# 17          17                 Scotch       18
# 18          18                Careone       19
# ...

# %%
combo = combined_data()
combo
# Out:
#         Unnamed: 0  item_id  sale_amount                      sale_date  \
# 0                0        1         13.0  Tue, 01 Jan 2013 00:00:00 GMT
# 1                1        1         11.0  Wed, 02 Jan 2013 00:00:00 GMT
# 2                2        1         14.0  Thu, 03 Jan 2013 00:00:00 GMT
# 3                3        1         13.0  Fri, 04 Jan 2013 00:00:00 GMT
# 4                4        1         10.0  Sat, 05 Jan 2013 00:00:00 GMT
# ...            ...      ...          ...                            ...
# 365195      365195       20         33.0  Wed, 27 Dec 2017 00:00:00 GMT
# 365196      365196       20         49.0  Thu, 28 Dec 2017 00:00:00 GMT
# 365197      365197       20         45.0  Fri, 29 Dec 2017 00:00:00 GMT
# 365198      365198       20         45.0  Sat, 30 Dec 2017 00:00:00 GMT
# 365199      365199       20         56.0  Sun, 31 Dec 2017 00:00:00 GMT
#
#         sale_id  store_id  Unnamed: 0_x           store_address   store_city  \
# ...

# %%
sales
# Out:
#         item  sale_amount                      sale_date  sale_id  store
# 0          1         13.0  Tue, 01 Jan 2013 00:00:00 GMT        1      1
# 1          1         11.0  Wed, 02 Jan 2013 00:00:00 GMT        2      1
# 2          1         14.0  Thu, 03 Jan 2013 00:00:00 GMT        3      1
# 3          1         13.0  Fri, 04 Jan 2013 00:00:00 GMT        4      1
# 4          1         10.0  Sat, 05 Jan 2013 00:00:00 GMT        5      1
# ...      ...          ...                            ...      ...    ...
# 912995    50         63.0  Wed, 27 Dec 2017 00:00:00 GMT   912996     10
# 912996    50         59.0  Thu, 28 Dec 2017 00:00:00 GMT   912997     10
# 912997    50         74.0  Fri, 29 Dec 2017 00:00:00 GMT   912998     10
# 912998    50         62.0  Sat, 30 Dec 2017 00:00:00 GMT   912999     10
# 912999    50         82.0  Sun, 31 Dec 2017 00:00:00 GMT   913000     10
#
# [913000 rows x 5 columns]

# %%
sales.index.rename('item_id')
# Out:
# RangeIndex(start=0, stop=913000, step=1, name='item_id')

# %%
sales
# Out:
#         item  sale_amount                      sale_date  sale_id  store
# 0          1         13.0  Tue, 01 Jan 2013 00:00:00 GMT        1      1
# 1          1         11.0  Wed, 02 Jan 2013 00:00:00 GMT        2      1
# 2          1         14.0  Thu, 03 Jan 2013 00:00:00 GMT        3      1
# 3          1         13.0  Fri, 04 Jan 2013 00:00:00 GMT        4      1
# 4          1         10.0  Sat, 05 Jan 2013 00:00:00 GMT        5      1
# ...      ...          ...                            ...      ...    ...
# 912995    50         63.0  Wed, 27 Dec 2017 00:00:00 GMT   912996     10
# 912996    50         59.0  Thu, 28 Dec 2017 00:00:00 GMT   912997     10
# 912997    50         74.0  Fri, 29 Dec 2017 00:00:00 GMT   912998     10
# 912998    50         62.0  Sat, 30 Dec 2017 00:00:00 GMT   912999     10
# 912999    50         82.0  Sun, 31 Dec 2017 00:00:00 GMT   913000     10
#
# [913000 rows x 5 columns]

# %%
stores
# Out:
#    Unnamed: 0            store_address   store_city  store_id store_state  \
# 0           0   12125 Alamo Ranch Pkwy  San Antonio         1          TX
# 1           1         9255 FM 471 West  San Antonio         2          TX
# 2           2  2118 Fredericksburg Rdj  San Antonio         3          TX
# 3           3          516 S Flores St  San Antonio         4          TX
# 4           4          1520 Austin Hwy  San Antonio         5          TX
# 5           5       1015 S WW White Rd  San Antonio         6          TX
# 6           6   12018 Perrin Beitel Rd  San Antonio         7          TX
# 7           7      15000 San Pedro Ave  San Antonio         8          TX
# 8           8       735 SW Military Dr  San Antonio         9          TX
# 9           9     8503 NW Military Hwy  San Antonio        10          TX
#
#    store_zipcode
# 0          78253
# 1          78251
# 2          78201
# 3          78204
# 4          78218
# 5          78220
# 6          78217
# ...

# %%
items
# Out:
#     Unnamed: 0             item_brand  item_id  \
# 0            0               Riceland        1
# 1            1                 Caress        2
# 2            2            Earths Best        3
# 3            3             Boars Head        4
# 4            4         Back To Nature        5
# 5            5           Sally Hansen        6
# 6            6     Twinings Of London        7
# 7            7          Lea & Perrins        8
# 8            8           Van De Kamps        9
# 9            9                  Ahold       10
# 10          10             Honest Tea       11
# 11          11                Mueller       12
# 12          12  Garnier Nutritioniste       13
# 13          13                Pamprin       14
# 14          14                  Suave       15
# 15          15             Burts Bees       16
# 16          16                  Ducal       17
# 17          17                 Scotch       18
# 18          18                Careone       19
# ...
